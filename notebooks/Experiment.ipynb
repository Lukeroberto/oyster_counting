# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.

# %%
import numpy as np
import cv2

import matplotlib.pyplot as plt
import algae

# %%
# %load_ext autoreload
# %autoreload 2

# %%
img = cv2.imread('tetra_ex.jpg', 0)
false = cv2.imread("empty_image.jpg", 0)
corrected = (img / false)

ims = [img, false, corrected]
fig = plt.figure(figsize=(8,11))
for i in range(3):
    ax = fig.add_subplot(1, 3, i + 1)
    ax.imshow(ims[i], cmap='gray')
    ax.axis('off')
plt.show()

# %%
algae.plot_thresholded_image(corrected)

# %%
cnt = algae.count_dots(corrected)
print("Number of dots: ", cnt)
# Out:
# Number of dots:  110
